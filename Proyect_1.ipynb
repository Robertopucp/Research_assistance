# %%
# !pip install "camelot-py[cv]" -q
# Out:
#      |████████████████████████████████| 40 kB 23 kB/s
#      |████████████████████████████████| 77 kB 3.5 MB/s
#      |████████████████████████████████| 5.6 MB 32.0 MB/s
#      |████████████████████████████████| 11.7 MB 28.8 MB/s
#      |████████████████████████████████| 3.6 MB 57.7 MB/s
# ...

# %%
# !apt-get install ghostscript
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono gsfonts libcupsfilters1 libcupsimage2
#   libgs9 libgs9-common libijs-0.35 libjbig2dec0 poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x poppler-utils fonts-japanese-mincho
#   | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts libcupsfilters1
#   libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 poppler-data
# 0 upgraded, 11 newly installed, 0 to remove and 37 not upgraded.
# Need to get 14.1 MB of archives.
# After this operation, 49.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# ...

# %%
import camelot as cm
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
tables[0].df.to_excel("base1.xlsx")

# %%
tables = cm.read_pdf("base_datos_notas.pdf", pages = "3", flavor = "lattice", backend="ghostscript", strip_text=' .\n')

# %%
tables[0].df
# Out:
#                                                    0   ...                                                 16
# 0   REGISTRODEACTADEEVALUACIÓNEDUCACIÓNSUPERIORTEC...  ...
# 1                                       NombredelIEST  ...                   CARRERA:ADMINISTRACIÓNDEEMPRESAS
# 2                               NúmerodeCódigomodular  ...
# 3                                        Departamento  ...  MENCION:PERIODOACADÉMICO:2019-IISECCIÓN:IITURN...
# 4                                   DireccióndelIESTP  ...
# 5   ResolucióndeAutorización(Tipo,númeroyfecha)RMN...  ...
# 6   ResolucióndeRevalidación(Tipo,númeroyfecha)RDN...  ...
# 7                                                  N°  ...
# 8                                                      ...                                      OBSERVACIONES
# 9                                                      ...
# 10                                                     ...
# 11                                                  1  ...
# ...

# %%
table = cm.read_pdf("base_datos_notas.pdf", pages = "3-208" , flavor = "lattice", backend="ghostscript", strip_text=' .\n')

# %%
table[205].df
# Out:
#     0   ...                                    16
# 0   N°  ...                         OBSERVACIONES
# 1       ...
# 2       ...
# 3       ...
# 4       ...
# 5   21  ...  Recuperación=Redaccióncomercial(NSP)
# 6   22  ...
# 7   23  ...
# 8   24  ...         Desaprobadoen2019-I=Logística
# 9   25  ...         Desaprobadoen2019-I=Logística
# 10  26  ...
# 11  27  ...
# 12  28  ...
# 13  29  ...
# 14  30  ...
# 15  31  ...
# 16  32  ...
# 17  33  ...
# 18  34  ...
# 19  35  ...
# 20  36  ...
# 21  37  ...
# 22  38  ...
# 23  39  ...
# 24  40  ...
#
# [25 rows x 17 columns]

# %%
tables[0].df

# %%
writer = pd.ExcelWriter('Educacion_base.xlsx')

for i in range(0,206):

  table[i].df.to_excel(writer, sheet_name = f'base_{ i }')

writer.save()

# %% [markdown]
# # Bussines managment data

# %%
base = pd.ExcelWriter('Administracion_empresas.xlsx')

for i in range(1,19):

    globals()[f'data{i}'] = pd.read_excel(base, sheet_name = f'Hoja{i}')

# %%
data1
# Out:
#          dni                              nombre  FG1  ...  period  section   shift
# 0   74945266          AMASIFUENCALIXTOErikRusber   16  ...  2019-2        2  diurno
# 1   77669026              ARIASMILLAXiomaraPaola   14  ...  2019-2        2  diurno
# 2   74089055          ARMASCARIJANOLeonelNicolas   15  ...  2019-2        2  diurno
# 3   74807392        BOGGIANOPIÑANAshileeJennifer   16  ...  2019-2        2  diurno
# 4   71838626      CARRANZAMOSQUEIRAAnibeShandell   16  ...  2019-2        2  diurno
# 5   73261487       CARRASCORIVERAEmyoriluReichel   15  ...  2019-2        2  diurno
# 6   48124545                  CHALCOCHALQUEDavid   15  ...  2019-2        2  diurno
# 7   75603049                CHILESALDIVARRichard   14  ...  2019-2        2  diurno
# 8   75447685           COSSERCARPIOElyKatherinne   14  ...  2019-2        2  diurno
# 9   74842138            CUNYACRUZWilderSebastian   17  ...  2019-2        2  diurno
# ...

# %%
base_final = data1.append(data2, ignore_index=True)

for i in range(3,19):

    base_final = base_final.append(globals()[f'data{i}'], ignore_index=True)

# %%
base_final
# Out:
#           dni                           nombre  FG1  FG2  ... FC29 FC30 FC31 FC32
# 0    74945266       AMASIFUENCALIXTOErikRusber   16   14  ...  NaN  NaN  NaN  NaN
# 1    77669026           ARIASMILLAXiomaraPaola   14   14  ...  NaN  NaN  NaN  NaN
# 2    74089055       ARMASCARIJANOLeonelNicolas   15   14  ...  NaN  NaN  NaN  NaN
# 3    74807392     BOGGIANOPIÑANAshileeJennifer   16    0  ...  NaN  NaN  NaN  NaN
# 4    71838626   CARRANZAMOSQUEIRAAnibeShandell   16   15  ...  NaN  NaN  NaN  NaN
# ..        ...                              ...  ...  ...  ...  ...  ...  ...  ...
# 225  76674075        CRUZPIZARROBrendaFiorella  NaN  NaN  ...   --   --   --   14
# 226   9692807            ALARCÓNORIHUELATeresa  NaN  NaN  ...   --   15   --   --
# 227  72229250  LEGUASOTOMAYORMadellinAntonella  NaN  NaN  ...   --   --   --   14
# 228  70884307             CANCHARIFELIXMaribel  NaN  NaN  ...  NaN  NaN  NaN  NaN
# ...

# %%
base_final = base_final.replace(np.nan, ".")
base_final
# Out:
#           dni                           nombre FG1 FG2  ... FC29 FC30 FC31 FC32
# 0    74945266       AMASIFUENCALIXTOErikRusber  16  14  ...    .    .    .    .
# 1    77669026           ARIASMILLAXiomaraPaola  14  14  ...    .    .    .    .
# 2    74089055       ARMASCARIJANOLeonelNicolas  15  14  ...    .    .    .    .
# 3    74807392     BOGGIANOPIÑANAshileeJennifer  16   0  ...    .    .    .    .
# 4    71838626   CARRANZAMOSQUEIRAAnibeShandell  16  15  ...    .    .    .    .
# ..        ...                              ...  ..  ..  ...  ...  ...  ...  ...
# 225  76674075        CRUZPIZARROBrendaFiorella   .   .  ...   --   --   --   14
# 226   9692807            ALARCÓNORIHUELATeresa   .   .  ...   --   15   --   --
# 227  72229250  LEGUASOTOMAYORMadellinAntonella   .   .  ...   --   --   --   14
# 228  70884307             CANCHARIFELIXMaribel   .   .  ...    .    .    .    .
# 229  74616106          HUANACOCHIMAICOCarolina   .   .  ...    .    .    .    .
#
# ...

# %%
cols = base_final[["pased", "disapproved", "period","section","shift"]]
cols
# Out:
#      pased  disapproved  period  section     shift
# 0        9            0  2019-2        2    diurno
# 1        9            0  2019-2        2    diurno
# 2        9            0  2019-2        2    diurno
# 3        8            1  2019-2        2    diurno
# 4        9            0  2019-2        2    diurno
# ..     ...          ...     ...      ...       ...
# 225      1            0  2019-2        5    diurno
# 226      1            0  2019-2        5  nocturno
# 227      1            0  2019-2        5  nocturno
# 228      1            0  2019-2        4  nocturno
# 229      1            0   2019-        4  nocturno
#
# [230 rows x 5 columns]

# %%
base_final = base_final.drop(["pased", "disapproved", "period","section","shift"], axis = 1)
base_final
# Out:
#           dni                           nombre FG1 FG2  ... FC29 FC30 FC31 FC32
# 0    74945266       AMASIFUENCALIXTOErikRusber  16  14  ...    .    .    .    .
# 1    77669026           ARIASMILLAXiomaraPaola  14  14  ...    .    .    .    .
# 2    74089055       ARMASCARIJANOLeonelNicolas  15  14  ...    .    .    .    .
# 3    74807392     BOGGIANOPIÑANAshileeJennifer  16   0  ...    .    .    .    .
# 4    71838626   CARRANZAMOSQUEIRAAnibeShandell  16  15  ...    .    .    .    .
# ..        ...                              ...  ..  ..  ...  ...  ...  ...  ...
# 225  76674075        CRUZPIZARROBrendaFiorella   .   .  ...   --   --   --   14
# 226   9692807            ALARCÓNORIHUELATeresa   .   .  ...   --   15   --   --
# 227  72229250  LEGUASOTOMAYORMadellinAntonella   .   .  ...   --   --   --   14
# 228  70884307             CANCHARIFELIXMaribel   .   .  ...    .    .    .    .
# 229  74616106          HUANACOCHIMAICOCarolina   .   .  ...    .    .    .    .
#
# ...

# %%
base_final = pd.concat([base_final, cols], axis=1)
base_final.to_csv("base_administracion.csv")

# %% [markdown]
# # Codes to Building data base

# %%
import camelot as cm
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import xlrd

# %%
file = 'Educacion_base.xlsx'

base_inicial = xlrd.open_workbook(file, on_demand=True)
sheet_names = base_inicial.sheet_names()

sheet_names
# Out:
# ['base_0',
#  'base_1',
#  'base_2',
#  'base_3',
#  'base_4',
#  'base_5',
#  'base_6',
#  'base_7',
#  'base_8',
#  'base_9',
#  'base_10',
#  'base_11',
#  'base_12',
#  'base_14',
#  'base_15',
#  'base_16',
#  'base_20',
#  'base_22',
#  'base_24',
#  'base_25',
#  'base_26',
#  'base_27',
#  'base_28',
#  'base_29',
#  'base_30',
#  'base_31',
#  'base_32',
#  'base_33',
#  'base_34',
#  'base_35',
#  'base_36',
#  'base_38',
#  'base_39',
#  'base_40',
#  'base_41',
#  'base_42',
#  'base_43',
#  'base_44',
#  'base_45',
#  'base_46',
#  'base_47',
#  'base_48',
#  'base_49',
#  'base_50',
#  'base_52',
#  'base_53',
#  'base_54',
#  'base_55',
#  'base_56',
#  'base_57',
#  'base_58',
#  'base_59',
#  'base_60',
#  'base_62',
#  'base_63',
#  'base_64',
#  'base_66',
#  'base_68',
#  'base_70',
#  'base_72',
#  'base_74',
#  'base_76',
#  'base_78',
#  'base_80',
#  'base_82',
#  'base_84',
#  'base_86',
#  'base_87',
#  'base_88',
#  'base_90',
#  'base_91',
#  'base_92',
# ...

# %%
base = pd.ExcelWriter('Educacion_base.xlsx')

for name in sheet_names:
 
    globals()[f'data_{name}'] = pd.read_excel(base, sheet_name= f'{name}')

# %%
base_tipo_1 = data_base_0.copy()
base_tipo_2 = data_base_1.copy()

# %%
base_tipo_1
# Out:
#      A  ... Unnamed: 19
# 0    0  ...         NaN
# 1    1  ...         NaN
# 2    2  ...         NaN
# 3    3  ...         NaN
# 4    4  ...         NaN
# 5    5  ...         NaN
# 6    6  ...         NaN
# 7    7  ...         NaN
# 8    8  ...         NaN
# 9    9  ...        comp
# 10  10  ...        192d
# 11  11  ...        192d
# 12  12  ...         NaN
# 13  13  ...         NaN
# 14  14  ...         NaN
# 15  15  ...         NaN
# 16  16  ...         NaN
# 17  17  ...         NaN
# 18  18  ...         NaN
# 19  19  ...         NaN
# 20  20  ...         NaN
# 21  21  ...         NaN
# 22  22  ...         NaN
# 23  23  ...         NaN
# 24  24  ...         NaN
# 25  25  ...         NaN
# 26  26  ...         NaN
# 27  27  ...         NaN
# 28  28  ...         NaN
# 29  29  ...         NaN
# 30  30  ...         NaN
#
# [31 rows x 20 columns]

# %%
#base = pd.ExcelWriter('Educacion_base.xlsx')

#for i in range(1,19):

    #globals()[f'data{i}'] = pd.read_excel(base, sheet_name = f'Hoja{i}')

# %%
if base_tipo_1.iloc[0,1] == "REGISTRODEACTADEEVALUACIÓNEDUCACIÓNSUPERIORTECNOLÓGICAAÑO2019-PERIODOLECTIVO2019-II":
  print("arriba")
  base_tipo_1 = base_tipo_1.iloc[9:]
# Out:
# arriba

# %%
base_tipo_1 = base_tipo_1.drop(base_tipo_1.columns[0:2], axis = 1)
base_tipo_1 = base_tipo_1.drop(labels=10, axis = 0)

# %%
base_tipo_1[1][9] = "dni"
base_tipo_1[2][9] = "nombre"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
a = base_tipo_1.iloc[1,-1]
b = base_tipo_1.iloc[1,-2]

print(a)
# Out:
# 192d

# %%
base_tipo_1 = base_tipo_1.dropna(how='all', axis = 1)

# %%
base_tipo_1.iloc[:, -2] = base_tipo_1.iloc[:, -2].fillna(b, inplace=False)
base_tipo_1.iloc[:, -1] = base_tipo_1.iloc[:, -1].fillna(a, inplace=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
base_tipo_1 = base_tipo_1.rename(columns=base_tipo_1.iloc[0])
base_tipo_1 = base_tipo_1.iloc[1:]
base_tipo_1 = base_tipo_1.drop( ['obs'] , axis=1)

# %%
base_tipo_1
# Out:
#          dni                              nombre FC21  ... disapproved ccspec  comp
# 11  74945266          AMASIFUENCALIXTOErikRusber   16  ...           0    100  192d
# 12  77669026              ARIASMILLAXiomaraPaola   14  ...           0    100  192d
# 13  74089055          ARMASCARIJANOLeonelNicolas   15  ...           0    100  192d
# 14  74807392        BOGGIANOPIÑANAshileeJennifer   16  ...           1    100  192d
# 15  71838626      CARRANZAMOSQUEIRAAnibeShandell   16  ...           0    100  192d
# 16  73261487       CARRASCORIVERAEmyoriluReichel   15  ...           0    100  192d
# 17  48124545                  CHALCOCHALQUEDavid   15  ...           0    100  192d
# 18  75603049                CHILESALDIVARRichard   14  ...           1    100  192d
# 19  75447685           COSSERCARPIOElyKatherinne   14  ...           1    100  192d
# 20  74842138            CUNYACRUZWilderSebastian   17  ...           0    100  192d
# ...

# %%
base_tipo_1
# Out:
#          dni                              nombre FC21  ... disapproved ccspec  comp
# 11  74945266          AMASIFUENCALIXTOErikRusber   16  ...           0    100  192d
# 12  77669026              ARIASMILLAXiomaraPaola   14  ...           0    100  192d
# 13  74089055          ARMASCARIJANOLeonelNicolas   15  ...           0    100  192d
# 14  74807392        BOGGIANOPIÑANAshileeJennifer   16  ...           1    100  192d
# 15  71838626      CARRANZAMOSQUEIRAAnibeShandell   16  ...           0    100  192d
# 16  73261487       CARRASCORIVERAEmyoriluReichel   15  ...           0    100  192d
# 17  48124545                  CHALCOCHALQUEDavid   15  ...           0    100  192d
# 18  75603049                CHILESALDIVARRichard   14  ...           1    100  192d
# 19  75447685           COSSERCARPIOElyKatherinne   14  ...           1    100  192d
# 20  74842138            CUNYACRUZWilderSebastian   17  ...           0    100  192d
# ...

# %%
data_base_1
# Out:
#      B  ... Unnamed: 19
# 0    0  ...         NaN
# 1    1  ...         NaN
# 2    2  ...         NaN
# 3    3  ...        comp
# 4    4  ...        192d
# 5    5  ...        192d
# 6    6  ...         NaN
# 7    7  ...         NaN
# 8    8  ...         NaN
# 9    9  ...         NaN
# 10  10  ...         NaN
# 11  11  ...         NaN
# 12  12  ...         NaN
# 13  13  ...         NaN
# 14  14  ...         NaN
# 15  15  ...         NaN
# 16  16  ...         NaN
# 17  17  ...         NaN
# 18  18  ...         NaN
# 19  19  ...         NaN
# 20  20  ...         NaN
# 21  21  ...         NaN
# 22  22  ...         NaN
# 23  23  ...         NaN
# 24  24  ...         NaN
# 25  25  ...         NaN
# 26  26  ...         NaN
# 27  27  ...         NaN
# 28  28  ...         NaN
# 29  29  ...         NaN
#
# [30 rows x 20 columns]

# %%
if base_tipo_2.iloc[0,1] == "N°":
  print("arriba")
  base_tipo_2 = base_tipo_2.iloc[3:]
# Out:
# arriba

# %%
base_tipo_2 = base_tipo_2.drop(base_tipo_2.columns[0:2], axis = 1)
base_tipo_2 = base_tipo_2.drop(labels=4, axis = 0)

# %%
base_tipo_2[1][3] = "dni"
base_tipo_2[2][3] = "nombre"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
a = base_tipo_1.iloc[1,-1]
b = base_tipo_1.iloc[1,-2]

print(a)
# Out:
# 192d

# %%
base_tipo_2 = base_tipo_2.dropna(how='all', axis = 1)

# %%
base_tipo_2.iloc[:, -2] = base_tipo_2.iloc[:, -2].fillna(b, inplace=False)
base_tipo_2.iloc[:, -1] = base_tipo_2.iloc[:, -1].fillna(a, inplace=False)

# %%
base_tipo_2 = base_tipo_2.rename(columns=base_tipo_2.iloc[0])
base_tipo_2 = base_tipo_2.iloc[1:]
base_tipo_2 = base_tipo_2.drop( ['obs'] , axis=1)

# %%
base_tipo_2 = base_tipo_2.dropna()

# %%
base_tipo_2
# Out:
#          dni                             nombre FC21  ... disapproved ccspec  comp
# 5   70464097               LOPEZVARGASJuanDiego   15  ...           0    100  192d
# 6   76358893             MALLQUISAICOFavioRonal   15  ...           0    100  192d
# 7   48605011           MENDOZAOBISPOLuisEnrique   15  ...           0    100  192d
# 8   72427894             MUÑOZPORTAElenaCecilia   16  ...           0    100  192d
# 9   77207847              NAVARROKOOMiguelAngel   15  ...           0    100  192d
# 10  48314340         PALACIOSSOTOMarisellaDaian   17  ...           0    100  192d
# 11  75271769        QUISPEMACAVILCALisethJanina   15  ...           0    100  192d
# 12  75199175          RAMIREZYUCRASergioNicolas   10  ...           7    100  192d
# 13  75430220                REYESNECIOSUPNicole   00  ...           9    100  192d
# 14  75154100  RODRIGUEZBEDREÑANAAndreaAlexandra   14  ...           1    100  192d
# ...

# %% [markdown]
# ## **Bucle final data**

# %%
for name in sheet_names:

  if globals()[f'data_{name}'].iloc[1,1] == "NombredelIEST":
    globals()[f'data_{name}'] = globals()[f'data_{name}'].iloc[9:]

    globals()[f'data_{name}'] = globals()[f'data_{name}'].drop(globals()[f'data_{name}'].columns[0:2], axis = 1)
    
    globals()[f'data_{name}'][1][9] = "dni"
    globals()[f'data_{name}'][2][9] = "nombre"

    a = globals()[f'data_{name}'].iloc[1,-1]
    b = globals()[f'data_{name}'].iloc[1,-2]  

    globals()[f'data_{name}'] = globals()[f'data_{name}'].dropna(how='all', axis = 1)

    globals()[f'data_{name}'].iloc[:, -2] = globals()[f'data_{name}'].iloc[:, -2].fillna(b, inplace=False)
    globals()[f'data_{name}'].iloc[:, -1] = globals()[f'data_{name}'].iloc[:, -1].fillna(a, inplace=False)

    globals()[f'data_{name}'] = globals()[f'data_{name}'].drop(labels=10, axis = 0) 

    globals()[f'data_{name}'] = globals()[f'data_{name}'].rename(columns=globals()[f'data_{name}'].iloc[0])
    globals()[f'data_{name}'] = globals()[f'data_{name}'].iloc[1:]
    globals()[f'data_{name}'] = globals()[f'data_{name}'].drop(['obs'] , axis = 1) 

    globals()[f'data_{name}'] = globals()[f'data_{name}'].dropna() 

  elif  globals()[f'data_{name}'].iloc[0,1] == "N°":
      globals()[f'data_{name}'] =  globals()[f'data_{name}'].iloc[3:]

      globals()[f'data_{name}'] = globals()[f'data_{name}'].drop(globals()[f'data_{name}'].columns[0:2], axis = 1)
      
      globals()[f'data_{name}'][1][3] = "dni"
      globals()[f'data_{name}'][2][3] = "nombre"

      a = globals()[f'data_{name}'].iloc[1,-1]
      b = globals()[f'data_{name}'].iloc[1,-2]

      globals()[f'data_{name}'] = globals()[f'data_{name}'].dropna(how='all', axis = 1)

      globals()[f'data_{name}'].iloc[:, -2] = globals()[f'data_{name}'].iloc[:, -2].fillna(b, inplace=False)
      globals()[f'data_{name}'].iloc[:, -1] = globals()[f'data_{name}'].iloc[:, -1].fillna(a, inplace=False)

      globals()[f'data_{name}'] = globals()[f'data_{name}'].drop(labels=4, axis = 0)

      globals()[f'data_{name}'] = globals()[f'data_{name}'].rename(columns=globals()[f'data_{name}'].iloc[0])
      globals()[f'data_{name}'] = globals()[f'data_{name}'].iloc[1:]
      globals()[f'data_{name}'] = globals()[f'data_{name}'].drop(['obs'] , axis = 1)  

      globals()[f'data_{name}'] = globals()[f'data_{name}'].dropna()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
data_base_0
# Out:
#          dni                              nombre GC1  ... disapproved ccspec  comp
# 11  74945266          AMASIFUENCALIXTOErikRusber  16  ...           0    100  192d
# 12  77669026              ARIASMILLAXiomaraPaola  14  ...           0    100  192d
# 13  74089055          ARMASCARIJANOLeonelNicolas  15  ...           0    100  192d
# 14  74807392        BOGGIANOPIÑANAshileeJennifer  16  ...           1    100  192d
# 15  71838626      CARRANZAMOSQUEIRAAnibeShandell  16  ...           0    100  192d
# 16  73261487       CARRASCORIVERAEmyoriluReichel  15  ...           0    100  192d
# 17  48124545                  CHALCOCHALQUEDavid  15  ...           0    100  192d
# 18  75603049                CHILESALDIVARRichard  14  ...           1    100  192d
# 19  75447685           COSSERCARPIOElyKatherinne  14  ...           1    100  192d
# 20  74842138            CUNYACRUZWilderSebastian  17  ...           0    100  192d
# ...

# %%
data_base_100
# Out:
#          dni                          nombre GC1  ... disapproved ccspec  comp
# 11  76332206     ALDERETEHUAMANCHARoggerYuri  17  ...           1    600  192n
# 12  76809041  ALDERETEHUAMANCHAYoelAlejandro  14  ...           0    600  192n
# 13  70171115        BRAVOCONDORJeremyAnthony  15  ...           0    600  192n
# 14  47647928             CHILENOQUINTOAlexis  18  ...           0    600  192n
# 15  75326256          DAVILABALLONKhaledOmar  18  ...           0    600  192n
# 16  48280601       GARCIAJIMENEZArnoldRobert  15  ...           0    600  192n
# 17  75270641      GONZALESCANTORINBorisBruce  13  ...           4    600  192n
# 18  73798038                LOPECHARAAlfredo  16  ...           0    600  192n
# 19  47306420          LOZANORUIZDiegoArmando  16  ...           0    600  192n
# 20  77709926        MAYTABARZOLAMiunserNiger  14  ...           0    600  192n
# 21  74094144       MELENDEZMELENDEZGuillermo  18  ...           0    600  192n
# ...

# %%
data_base_204
# Out:
#          dni                            nombre GC24  ... disapproved ccspec  comp
# 11  71804453       ACEVEDOMARQUINAJulisaRosita   16  ...           1    700  205n
# 12  73980064          AGUILARROJASKarolXibelli   18  ...           0    700  205n
# 13  77463621        ARQUECAHUASCANCOMariaEliza   00  ...           9    700  205n
# 14  75199304           BRIOSORONQUILLOAdelinda   00  ...           7    700  205n
# 15  70521281             CANREACCOMelaniaErika   16  ...           1    700  205n
# 16  76304578  CARBAJALGALARZAFranccescaMiluska   18  ...           0    700  205n
# 17  70977028          CHAVEZBELTRANMonicaDiana   16  ...           0    700  205n
# 18  74710787               CRUZARISTAJacquelin   18  ...           0    700  205n
# 19  74434035         DOMINGUEZSAAVEDRALuzMaria   00  ...          10    700  205n
# 20  44454663    DURANDDURANDGuianellaGuadalupe   16  ...           0    700  205n
# ...

# %%
base_completa = data_base_0.copy()
sheet_names1 = sheet_names[1:]

# %%
for name in sheet_names1:

  base_completa = base_completa.append(globals()[f'data_{name}'], ignore_index=True)

# %%
cols = base_completa[["pased", "disapproved", "ccspec","comp"]]

# %%
print(cols)
# Out:
#      pased disapproved ccspec  comp
# 0        9           0    100  192d
# 1        9           0    100  192d
# 2        9           0    100  192d
# 3        8           1    100  192d
# 4        9           0    100  192d
# ...    ...         ...    ...   ...
# 3097     9           1    700  205n
# 3098     9           1    700  205n
# 3099     9           1    700  205n
# 3100     1           0    700  205n
# 3101     1           0    700  205n
#
# [3102 rows x 4 columns]

# %%
base_completa = base_completa.drop(["nombre","pased", "disapproved", "ccspec","comp"], axis = 1)

# %%
base_completa = pd.concat([base_completa, cols], axis=1)
base_completa
# Out:
#            dni  GC1  GC2  GC3  GC4  ... FC119 pased disapproved ccspec  comp
# 0     74945266   16   14   16   18  ...   NaN     9           0    100  192d
# 1     77669026   14   14   15   17  ...   NaN     9           0    100  192d
# 2     74089055   15   14   15   19  ...   NaN     9           0    100  192d
# 3     74807392   16   00   15   16  ...   NaN     8           1    100  192d
# 4     71838626   16   15   16   15  ...   NaN     9           0    100  192d
# ...        ...  ...  ...  ...  ...  ...   ...   ...         ...    ...   ...
# 2387  44326402  NaN  NaN  NaN  NaN  ...   NaN     9           1    700  205n
# 2388  75216028  NaN  NaN  NaN  NaN  ...   NaN     9           1    700  205n
# 2389  73561224  NaN  NaN  NaN  NaN  ...   NaN     9           1    700  205n
# 2390  73875551  NaN  NaN  NaN  NaN  ...   NaN     1           0    700  205n
# 2391  48595279  NaN  NaN  NaN  NaN  ...   NaN     1           0    700  205n
#
# [2392 rows x 272 columns]

# %%
carrera = pd.read_excel("cursos.xlsx", sheet_name = "carrera")
complement = pd.read_excel("cursos.xlsx", sheet_name = "complemento")

# %%
carrera
# Out:
#    ccspec                     carrera
# 0     100  Administracion de empresas
# 1     200   Computacion e informatica
# 2     300                Contabilidad
# 3     400    Electrotecnia industrial
# 4     500         Mecanica automotriz
# 5     600      Mecanica de produccion
# 6     700      Secretariado ejecutivo

# %%
complement
# Out:
#     comp  period  section     shift
# 0   191d       1        1    diurno
# 1   192d       1        2    diurno
# 2   193d       1        3    diurno
# 3   194d       1        4    diurno
# 4   195d       1        5    diurno
# 5   196d       1        6    diurno
# 6   191n       1        1  nocturno
# 7   192n       1        2  nocturno
# 8   193n       1        3  nocturno
# 9   194n       1        4  nocturno
# 10  195n       1        5  nocturno
# 11  196n       1        6  nocturno
# 12  201d       2        1    diurno
# 13  202d       2        2    diurno
# 14  203d       2        3    diurno
# 15  204d       2        4    diurno
# 16  205d       2        5    diurno
# 17  206d       2        6    diurno
# 18  201n       2        1  nocturno
# 19  202n       2        2  nocturno
# 20  203n       2        3  nocturno
# 21  204n       2        4  nocturno
# 22  205n       2        5  nocturno
# 23  206n       2        6  nocturno

# %%
base_completa = pd.merge(base_completa, carrera, how="left", on="ccspec")

# %%
base_completa= pd.merge(base_completa, complement, how="left", on="comp")

# %%
base_completa
# Out:
#            dni  GC1  GC2  ... period section     shift
# 0     74945266   16   14  ...      1       2    diurno
# 1     77669026   14   14  ...      1       2    diurno
# 2     74089055   15   14  ...      1       2    diurno
# 3     74807392   16   00  ...      1       2    diurno
# 4     71838626   16   15  ...      1       2    diurno
# ...        ...  ...  ...  ...    ...     ...       ...
# 2387  44326402  NaN  NaN  ...      2       5  nocturno
# 2388  75216028  NaN  NaN  ...      2       5  nocturno
# 2389  73561224  NaN  NaN  ...      2       5  nocturno
# 2390  73875551  NaN  NaN  ...      2       5  nocturno
# 2391  48595279  NaN  NaN  ...      2       5  nocturno
#
# [2392 rows x 276 columns]

# %%
cols = base_completa.columns.tolist()
cols
# Out:
# ['dni',
#  'GC1',
#  'GC2',
#  'GC3',
#  'GC4',
#  'GC5',
#  'FC99',
#  'FC100',
#  'FC101',
#  'FC102',
#  'GC6',
#  'GC7',
#  'GC8',
#  'FC72',
#  'FC73',
#  'FC74',
#  'FC75',
#  'GC9',
#  'GC10',
#  'GC11',
#  'FC84',
#  'FC85',
#  'FC86',
#  'FC87',
#  'FC131',
#  'FC132',
#  'FC133',
#  'FC31',
#  'FC32',
#  'FC33',
#  'GC12',
#  'GC13',
#  'GC14',
#  'GC15',
#  'FC216',
#  'FC61',
#  'FC62',
#  'FC34',
#  'FC35',
#  'FC36',
#  'GC16',
#  'GC17',
#  'GC18',
#  'FC213',
#  'FC214',
#  'FC215',
#  'GC19',
#  'GC20',
#  'GC21',
#  'GC22',
#  'GC23',
#  'GC24',
#  'GC25',
#  'GC26',
#  'FC79',
#  'FC80',
#  'FC81',
#  'FC82',
#  'FC83',
#  'FC88',
#  'FC89',
#  'FC90',
#  'FC91',
#  'FC92',
#  'FC93',
#  'FC44',
#  'FC45',
#  'FC46',
#  'FC47',
#  'FC63',
#  'FC64',
#  'FC65',
#  'FC66',
#  'GC27',
#  'GC28',
#  'GC30',
#  'FC94',
#  'FC95',
#  'FC96',
#  'FC97',
#  'FC98',
#  'FC194',
#  'FC195',
#  'FC196',
#  'FC197',
#  'FC41',
#  'FC42',
#  'FC43',
#  'FC1',
#  'FC2',
# ...

# %%
col_1 = ['dni', 'period']

del cols[273]
del cols[0]

cols
# Out:
# ['GC1',
#  'GC2',
#  'GC3',
#  'GC4',
#  'GC5',
#  'FC99',
#  'FC100',
#  'FC101',
#  'FC102',
#  'GC6',
#  'GC7',
#  'GC8',
#  'FC72',
#  'FC73',
#  'FC74',
#  'FC75',
#  'GC9',
#  'GC10',
#  'GC11',
#  'FC84',
#  'FC85',
#  'FC86',
#  'FC87',
#  'FC131',
#  'FC132',
#  'FC133',
#  'FC31',
#  'FC32',
#  'FC33',
#  'GC12',
#  'GC13',
#  'GC14',
#  'GC15',
#  'FC216',
#  'FC61',
#  'FC62',
#  'FC34',
#  'FC35',
#  'FC36',
#  'GC16',
#  'GC17',
#  'GC18',
#  'FC213',
#  'FC214',
#  'FC215',
#  'GC19',
#  'GC20',
#  'GC21',
#  'GC22',
#  'GC23',
#  'GC24',
#  'GC25',
#  'GC26',
#  'FC79',
#  'FC80',
#  'FC81',
#  'FC82',
#  'FC83',
#  'FC88',
#  'FC89',
#  'FC90',
#  'FC91',
#  'FC92',
#  'FC93',
#  'FC44',
#  'FC45',
#  'FC46',
#  'FC47',
#  'FC63',
#  'FC64',
#  'FC65',
#  'FC66',
#  'GC27',
#  'GC28',
#  'GC30',
#  'FC94',
#  'FC95',
#  'FC96',
#  'FC97',
#  'FC98',
#  'FC194',
#  'FC195',
#  'FC196',
#  'FC197',
#  'FC41',
#  'FC42',
#  'FC43',
#  'FC1',
#  'FC2',
#  'FC3',
# ...

# %%
list_columns = col_1 + cols

# %%
base_completa = base_completa[list_columns]
base_completa
# Out:
#            dni  period  GC1  ...                     carrera section     shift
# 0     74945266       1   16  ...  Administracion de empresas       2    diurno
# 1     77669026       1   14  ...  Administracion de empresas       2    diurno
# 2     74089055       1   15  ...  Administracion de empresas       2    diurno
# 3     74807392       1   16  ...  Administracion de empresas       2    diurno
# 4     71838626       1   16  ...  Administracion de empresas       2    diurno
# ...        ...     ...  ...  ...                         ...     ...       ...
# 2387  44326402       2  NaN  ...      Secretariado ejecutivo       5  nocturno
# 2388  75216028       2  NaN  ...      Secretariado ejecutivo       5  nocturno
# 2389  73561224       2  NaN  ...      Secretariado ejecutivo       5  nocturno
# 2390  73875551       2  NaN  ...      Secretariado ejecutivo       5  nocturno
# 2391  48595279       2  NaN  ...      Secretariado ejecutivo       5  nocturno
#
# ...

# %%
base_completa = base_completa.replace('--', None)
#base_completa = base_completa.replace('REGISTRODEACTADEEVALUACIÓNEDUCACIÓNSUPERIORTECNOLÓGICAAÑO2019-PERIODOLECTIVO2019-IIEVALUACIÓNEXTRAORDINARIA', None)

# %%
base_completa.iloc[:,271:276]
# Out:
#      ccspec  comp                     carrera  section     shift
# 0       100  192d  Administracion de empresas        2    diurno
# 1       100  192d  Administracion de empresas        2    diurno
# 2       100  192d  Administracion de empresas        2    diurno
# 3       100  192d  Administracion de empresas        2    diurno
# 4       100  192d  Administracion de empresas        2    diurno
# ...     ...   ...                         ...      ...       ...
# 2387    700  205n      Secretariado ejecutivo        5  nocturno
# 2388    700  205n      Secretariado ejecutivo        5  nocturno
# 2389    700  205n      Secretariado ejecutivo        5  nocturno
# 2390    700  205n      Secretariado ejecutivo        5  nocturno
# 2391    700  205n      Secretariado ejecutivo        5  nocturno
#
# [2392 rows x 5 columns]

# %%
base_completa1 = base_completa.iloc[:,0:271].astype(float, errors = 'raise')

base_completa2 = base_completa.iloc[:,271:276]

base_completa = pd.concat([base_completa1, base_completa2], axis=1)

# %%
base_completa
# Out:
#              dni  period   GC1  ...                     carrera  section     shift
# 0     74945266.0     1.0  16.0  ...  Administracion de empresas        2    diurno
# 1     77669026.0     1.0  14.0  ...  Administracion de empresas        2    diurno
# 2     74089055.0     1.0  15.0  ...  Administracion de empresas        2    diurno
# 3     74807392.0     1.0  16.0  ...  Administracion de empresas        2    diurno
# 4     71838626.0     1.0  16.0  ...  Administracion de empresas        2    diurno
# ...          ...     ...   ...  ...                         ...      ...       ...
# 2387  44326402.0     2.0   NaN  ...      Secretariado ejecutivo        5  nocturno
# 2388  75216028.0     2.0   NaN  ...      Secretariado ejecutivo        5  nocturno
# 2389  73561224.0     2.0   NaN  ...      Secretariado ejecutivo        5  nocturno
# 2390  73875551.0     2.0   NaN  ...      Secretariado ejecutivo        5  nocturno
# ...

# %%
base_completa = base_completa.sort_values(by=['dni', 'period'])

# %%
base_completa = base_completa.replace(np.nan, ".")

# %%
base_completa
# Out:
#              dni  period GC1  ...                     carrera section     shift
# 2294    940893.0     2.0   .  ...      Secretariado ejecutivo       1  nocturno
# 456     961093.0     1.0  16  ...                Contabilidad       2    diurno
# 571     961093.0     1.0   .  ...                Contabilidad       4  nocturno
# 1823    961093.0     2.0   .  ...                Contabilidad       5  nocturno
# 2179   4647843.0     2.0   .  ...      Mecanica de produccion       1    diurno
# ...          ...     ...  ..  ...                         ...     ...       ...
# 209   80287733.0     1.0   .  ...  Administracion de empresas       6  nocturno
# 719   80347844.0     1.0   .  ...    Electrotecnia industrial       4    diurno
# 1986  80347844.0     2.0   .  ...    Electrotecnia industrial       5    diurno
# 920   80652103.0     1.0   .  ...         Mecanica automotriz       6  nocturno
# 1172  90035159.0     2.0   .  ...  Administracion de empresas       1    diurno
#
# ...

# %%
base_completa.to_csv("base_completa.csv")
